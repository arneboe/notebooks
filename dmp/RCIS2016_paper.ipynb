accelerations[-1] = 0
positions = np.asarray(positions)
velocities = np.asarray(velocities)
accelerations = np.asarray(accelerations)
executionTime = dt * len(positions)
times, step = np.linspace(start=0.0, stop=dt * len(positions), num = len(positions), retstep=True)

# %% [markdown]
# #### Move goal bending

# %%
def move_goal(use_scaling):
    plt.plot(times, positions, "r", label="Original Trajectory")

    lastPhaseValue = 0.1
    numWeights = 100
    overlap = 0.2
    endTime = executionTime
    endPos = positions[-1]


    cs = CS(executionTime, lastPhaseValue)
    dmp = DmpWithImitation(executionTime, positions[0],
                           (positions[1] - positions[0]) / dt, positions[-1],
                           cs, numWeights, overlap, use_scaling)
    dmp.imitate(times, positions, dt)

    cs2 = CS(executionTime, lastPhaseValue)
    dmp.reset(cs2, positions[-1] + 10, executionTime, positions[0])
    (ts, ys, yds) = dmp.run(0.001)
    plt.plot(ts, ys, "m--", label="Trajectories with shifted goal positions")

    for i in [20, 30,40, 50, -10, -20, -30, -40, -50]:
        cs2 = CS(executionTime, lastPhaseValue)
        dmp.reset(cs2, positions[-1] + i, executionTime, positions[0])
        (ts, ys, yds) = dmp.run(0.001)
        plt.plot(ts, ys, "m--")





    #ax2.plot(ts, yds, "c--")
    plt.xlabel('Time in Seconds', fontsize=22)
    plt.ylabel('X-Position of Kick Trajectory', fontsize=22)
    plt.legend(loc=3)

# %%
plt.figure()
move_goal(True)
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
move_goal(False)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Mülling DMP bending WITHOUT velocity scaling

# %%
lastPhaseValue = 0.1
numWeights = 100
overlap = 0.2

cs = CS(executionTime, lastPhaseValue)
scale_velocity = False
dmp = MuellingDmp(executionTime, positions[0], velocities[0],
                  accelerations[0], positions[-1], velocities[-1],
                  cs, numWeights, overlap, scale_velocity)
dmp.imitate(times, positions, velocities, accelerations, dt)

plt.figure()

cs = CS(executionTime, lastPhaseValue)
dmp.reset(cs, positions[-1], executionTime, dmp.y0, 0)
(ts, ys, yds, ydds) = dmp.run(0.001)
plt.plot(ts, ys, "m--", label="Trajectories with changed goal velocity")

for vel in [300, 600, 900, 1200, 1500, 1800, 2100, 2300, 2600, 2900]:
    cs = CS(executionTime, lastPhaseValue)
    dmp.reset(cs, positions[-1], executionTime, dmp.y0, vel)
    (ts, ys, yds, ydds) = dmp.run(0.001)
    plt.plot(ts, ys, "m--")
    
plt.plot(times, positions, "r", label="Original trajectory")
plt.legend(loc=3)
plt.xlabel('Time in Seconds', fontsize=22)
plt.ylabel('X-Position of Kick Trajectory', fontsize=22)
plt.savefig("/home/arne/git/notebooks/dmp/muelling_dmp_bend_without_scale.pdf", format='pdf')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Mülling DMP bending WITH velocity scaling

# %%
lastPhaseValue = 0.1
numWeights = 100
overlap = 0.2

cs = CS(executionTime, lastPhaseValue)
scale_velocity = True
dmp = MuellingDmp(executionTime, positions[0], velocities[0],
                  accelerations[0], positions[-1], velocities[-1],
                  cs, numWeights, overlap, scale_velocity)
dmp.imitate(times, positions, velocities, accelerations, dt)

plt.figure()

cs = CS(executionTime, lastPhaseValue)
dmp.reset(cs, positions[-1], executionTime, dmp.y0, 0)
(ts, ys, yds, ydds) = dmp.run(0.001)
plt.plot(ts, ys, "m--", label="Trajectories with changed goal velocity")

for vel in [300, 600, 900, 1200, 1500, 1800, 2100, 2300, 2600, 2900]:
    cs = CS(executionTime, lastPhaseValue)
    dmp.reset(cs, positions[-1], executionTime, dmp.y0, vel)
    (ts, ys, yds, ydds) = dmp.run(0.001)
    plt.plot(ts, ys, "m--")
    
plt.plot(times, positions, "r", label="Original trajectory")
plt.legend(loc=3)
plt.xlabel('Time in Seconds', fontsize=22)
plt.ylabel('X-Position of Kick Trajectory', fontsize=22)
plt.savefig("/home/arne/git/notebooks/dmp/muelling_dmp_bend_with_scale.pdf", format='pdf')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Mülling DMP time scaling

# %%
plt.figure()


lastPhaseValue = 0.1
numWeights = 100
overlap = 0.2
endTime = executionTime
endPos = positions[-1]


cs = CS(executionTime, lastPhaseValue)
dmp = DmpWithImitation(executionTime, positions[0],
                       (positions[1] - positions[0]) / dt, positions[-1],
                       cs, numWeights, overlap, False)
dmp.imitate(times, positions, dt)

cs2 = CS(executionTime - 0.5, lastPhaseValue)
dmp.reset(cs2, positions[-1], executionTime - 0.5, positions[0])
(ts, ys, yds) = dmp.run(0.001)
plt.plot(ts, ys, "b--", label="Trajectories with scaled execution time")


for i in [0.5, 0.4, 0.3, 0.2, 0.1, -0.1, -0.2, -0.3, -0.4]:
    cs2 = CS(executionTime + i, lastPhaseValue)
    dmp.reset(cs2, positions[-1], executionTime+ i, positions[0])
    (ts, ys, yds) = dmp.run(0.001)
    plt.plot(ts, ys, "b--")


cs2 = CS(executionTime, lastPhaseValue)
dmp.reset(cs2, positions[-1], executionTime, positions[0])
(ts, ys, yds) = dmp.run(0.001)
plt.plot(ts, ys, "r", label="Imitated Trajectory")

#ax2.plot(ts, yds, "c--")
plt.xlabel('Time in Seconds', fontsize=22)
plt.ylabel('X-Position of Kick Trajectory', fontsize=22)
plt.ylim(-100, 60)
plt.legend(loc=3)
plt.savefig("/home/arne/git/notebooks/dmp/dmp_time_scale.pdf", format='pdf')
# Out:
# <img src="data:image/png;base64,...">
